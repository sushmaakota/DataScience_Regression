# %% [markdown]
# # Simple Linear Regression Application
#
#
# ## Modelling the relationship between Sales and Advertising features

# %%
#25-03-2023                                   21b01a1288

# %% [markdown]
# ## Project overview
#
#
# In this project, a Simple Linear Regression model needs to be applied for the linear relationship between Sales and Advertising dataset.

# %% [markdown]
# ###  Linear Regression
#
#
# Linear Regression is a statistical technique which is used to find the linear relationship between dependent and one or more independent variables. This technique is applicable for Supervised learning Regression problems where we try to predict a continuous variable.
#
#
# Linear Regression can be further classified into two types – Simple and Multiple Linear Regression. In this project,  Simple Linear Regression technique needs to applied where it contains one independent and one dependent variable. It is the simplest form of Linear Regression where we fit a straight line to the data.

# %% [markdown]
# ###  Simple Linear Regression (SLR)
#
# Simple Linear Regression (or SLR) is the simplest model in machine learning. It models the linear relationship between the independent and dependent variables.
#
# In this project, there is one independent or input variable which represents the Sales data and is denoted by X. Similarly, there is one dependent or output variable which represents the Advertising data and is denoted by y. We want to build a linear relationship between these variables. This linear relationship can be modelled by mathematical equation of the form:-
#
#
#                  Y = β0   + β1*X    -------------   (1)
#
#
# In this equation, X and Y are called independent and dependent variables respectively,
#
# β1 is the coefficient for independent variable and
#
# β0 is the constant term.
#
# β0 and β1 are called parameters of the model.
#
#
#
# For simplicity, we can compare the above equation with the basic line equation of the form:-
#
#                    y = ax + b       ----------------- (2)
#
# We can see that
#
# slope of the line is given by, a =  β1,  and
#
# intercept of the line by b =  β0.
#
#
# In this Simple Linear Regression model, we want to fit a line which estimates the linear relationship between X and Y. So, the question of fitting reduces to estimating the parameters of the model β0 and β1.

# %% [markdown]
# ## The problem statement
#
# The aim of building a machine learning model is to solve a problem and to define a metric to measure model performance.
#
# The problem is to model and investigate the linear relationship between Sales and Advertising dataset
#
# Metric for model performance is RMSE

# %%
# Import necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
% matplotlib inline 

# The above command sets the backend of matplotlib to the 'inline' backend. 
# It means the output of plotting commands is displayed inline.
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# ## Dataset Loading

# %%
# Import the data
data = pd.read_csv('sales.csv')

# %% [markdown]
# ## Exploratory data analysis

# %%
# Exploratory data analysis
data.head()
# View the dimensions of df
data.shape
# Out:
# (1534, 2)

# %% [markdown]
# ### pandas head() method
#
# I viewed the top 5 rows of the pandas dataframe with the pandas head() method.

# %%
# View the top 5 rows of df
data.head()
# Out:
#    Sales  Advertising
# 0   12.0           15
# 1   20.5           16
# 2   21.0           18
# 3   15.5           27
# 4   15.3           21

# %% [markdown]
# ### pandas info() method
#
# I viewed the summary of the dataframe with the pandas info() method.

# %%
# View dataframe summary
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1534 entries, 0 to 1533
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        1534 non-null   float64
#  1   Advertising  1534 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 24.1 KB

# %% [markdown]
# ### pandas describe() method
#
# Descriptive statistics of the dataframe with the pandas describe() method.

# %%
# View descriptive statistics
data.describe()
# Out:
#              Sales  Advertising
# count  1534.000000  1534.000000
# mean     56.451369    54.595176
# std      24.955247    26.042035
# min      12.000000     1.000000
# 25%      34.925000    32.000000
# 50%      56.850000    54.000000
# 75%      78.375000    77.000000
# max      98.800000    99.000000

# %% [markdown]
# ## Independent and Dependent Variables

# %%
# Declare feature variable X and target variable y using df[col].values
# Sales and Advertising data values are given by X and y respectively.
# Values attribute of pandas dataframe returns the numpy arrays.
x = data['Sales'].values
y = data['Advertising'].values
x
y
# Out:
# array([15, 16, 18, ..., 91, 73, 87], dtype=int64)

# %% [markdown]
# ## Visual exploratory data analysis

# %%
# Plot scatter plot with blue dots between X and y
# xlabel with Sales
# y label with Advertising
# plot name as Relationship between Sales and Advertising 
plt.xlabel("Sales")
plt.ylabel('Advertising')
plt.title('Relationship between Sales and advertising')
plt.grid(linestyle='--',linewidth=1)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Checking dimensions of X and y
#
# We need to check the dimensions of X and y to make sure they are in right format for Scikit-Learn API.
#
# It is an important precursor to model building.

# %%
# Print the dimensions of X and y using shape and ensure that same size will be for X and y
print([x.shape,y.shape])
# Out:
# [(1534,), (1534,)]

# %% [markdown]
# ## Reshaping X and y
#
# Since we are working with only one feature variable, so we need to reshape using Numpy reshape() method.
#
# It specifies first dimension to be -1, which means "unspecified".
#
# Its value is inferred from the length of the array and the remaining dimensions.
# Reshape with following statements
# X = X.reshape(-1,1)
# y = y.reshape(-1,1)

# %%
# Reshape X and y
x = x.reshape(-1,1)
y = y.reshape(-1,1)

# %%
# Print the dimensions of X and y after reshaping
print(x.shape)
print(y.shape)
# Out:
# (1534, 1)
# (1534, 1)

# %% [markdown]
# ## Difference in dimensions of X and y after reshaping
#
#
# We can see the difference in diminsions of X and y before and after reshaping.
#
# It is essential in this case because getting the feature and target variable right is an important precursor to model building.

# %% [markdown]
# ## Train test split

# %%
# Split X and y into training and test data sets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=1/3, random_state = 0)

# %%
# Print the dimensions of X_train,X_test,y_train,y_test using shape attribute
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1022, 1)
# (1022, 1)
# (512, 1)
# (512, 1)

# %% [markdown]
# ## Mechanics of the model

# %%
# Fit the linear model
from sklearn.linear_model import LinearRegression
# Instantiate the linear regression object lm
lm = LinearRegression()
# Train the model using training data sets
lm.fit(x_train,y_train)
# Predict on the test data
y_pred = lm.predict(x_test)

# %% [markdown]
# ## Model slope and intercept term
#
# Identify model slope and intercept for the given dataset using following statements
# c = lm.coef_
# m = lm.intercept_
#
# and print them

# %%
# Compute model slope and intercept
a = lm.coef_
b = lm.intercept_
print("Estimated model slope  a:",a)
print("Estimated model slope  b:",b)
# Out:
# Estimated model slope  a: [[0.06669454]]
# Estimated model slope  b: [50.6188533]

# %%
# print fitted regression line in the form of y = m * x + b
print("y = 0.06669454 * x + 50.6188533 ")
# Out:
# y = 0.06669454 * x + 50.6188533

# %% [markdown]
# ## Making predictions
#
#
# Predict the Y ( Advertising value) with given random value of X(Sale value)

# %%
# Predicting Advertising values
# Predicting Advertising values on Sale values.
print(lm.predict(y))
# Out:
# [[51.61927146]
#  [51.68596601]
#  [51.8193551 ]
#  ...
#  [56.68805683]
#  [55.48755503]
#  [56.42127866]]

# %%
# To make an individual prediction using the linear regression model.
print(str(lm.predict([[24]])))
# Out:
# [[52.21952236]]

# %% [markdown]
# ## Regression metrics for model performance
#
#
# Now, it is the time to evaluate model performance.
#
# For regression problems, there are two ways to compute the model performance. They are RMSE (Root Mean Square Error) and R-Squared Value. These are explained below:-
#
#
# ### RMSE
#
# RMSE is the standard deviation of the residuals. So, RMSE gives us the standard deviation of the unexplained variance by the model. It can be calculated by taking square root of Mean Squared Error.
# RMSE is an absolute measure of fit. It gives us how spread the residuals are, given by the standard deviation of the residuals. The more concentrated the data is around the regression line, the lower the residuals and hence lower the standard deviation of residuals. It results in lower values of RMSE. So, lower values of RMSE indicate better fit of data.
# Use the following code to get RMSE
# from sklearn.metrics import mean_squared_error
# mse = mean_squared_error(y_test, y_pred)
# rmse = np.sqrt(mse)

# %%
# Calculate and print Root Mean Square Error(RMSE)
from sklearn.metrics import mean_squared_error
mse =  mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
print("RMSE Value : {:.4f}".format(rmse))
# Out:
# RMSE Value : 25.8556

# %% [markdown]
# ## Interpretation and Conclusion
#
# Draw the scatter plot with regresion line between  X and Y

# %%
# Plot the Regression Line
plt.scatter(x, y, label='Scatter Plot')
plt.plot(x_test,y_pred,color = 'black', linewidth=3, label = 'Regression Line')
plt.title('Relationship between Sales and Advertising')
plt.xlabel('Sales')
plt.ylabel('Advertising')
plt.legend(loc=4)
plt.show()
